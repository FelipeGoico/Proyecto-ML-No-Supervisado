# %% [markdown]
# # 🧠 Proyecto: Exploración y Propuesta de Problema con Machine Learning No Supervisado
#
# ## Introducción
#
# El **Machine Learning no supervisado** constituye una de las ramas más potentes de la inteligencia artificial moderna, orientada a descubrir estructuras ocultas, patrones complejos y relaciones latentes dentro de los datos sin disponer de etiquetas previas. Este enfoque permite analizar fenómenos naturales, comportamientos o características de entornos complejos, facilitando la toma de decisiones autónomas basadas en la observación directa de la realidad.
#
# ### 🎯 Visión del Proyecto: Inteligencia Rural para el Sur de Chile
#
# **Nuestro objetivo principal** es desarrollar una **inteligencia general orientada a la economía circular**, específicamente diseñada para el contexto rural del sur de Chile, capaz de:
#
# - 🌳 **Sistemas Silvopastoriles Inteligentes**: Monitoreo automatizado de **agroforestería silvopastoril** integrando árboles, arbustos comestibles y pasturas para optimización de nutrientes, sombra y regeneración del suelo
# - 🥛 **Evaluar la calidad de la leche** mediante análisis automatizado en sistemas de producción regenerativa
# - 🔊 **Detectar comportamientos y bienestar animal** a través de señales auditivas con sensores IoT en ambientes silvopastoriles
# - 🤖 **Complementarse con innovación robótica** para automatización de procesos en **silvopastoreo regenerativo**
# - 🌱 **Monitoreo de regeneración del suelo** mediante análisis de patrones de crecimiento, biodiversidad y salud del ecosistema integrado
#
# Esta inteligencia distribuida representará un **ecosistema tecnológico integrado** que contribuya a la sustentabilidad, eficiencia, bienestar animal y regeneración ecológica en la región mediante prácticas silvopastoriles modernas.
#
# ### Relevancia e Impacto Global y Regional
#
# A nivel global, las técnicas no supervisadas han transformado diversos sectores, pero su **aplicación específica al contexto del sur de Chile** presenta oportunidades únicas:
#
# - **Agroindustria Sustentable**: Monitoreo automatizado de cultivos y detección temprana de enfermedades vegetales
# - **Ganadería Inteligente**: Análisis de sonidos para detectar estrés, enfermedad o comportamientos anómalos en animales
# - **Calidad Alimentaria**: Control automatizado de productos lácteos y detección de anomalías en parámetros físico-químicos
# - **Economía Circular**: Optimización de recursos mediante inteligencia distribuida con sensores de campo
# - **Desarrollo Regional**: Tecnología aplicada que fortalezca la competitividad del sur de Chile
#
# ### Contexto y Motivación Específica
#
# El presente proyecto se enmarca dentro de una visión de **inteligencia artificial aplicada específicamente al silvopastoreo regenerativo del sur de Chile**, donde la integración de diferentes fuentes de datos —imágenes, audio y análisis físico-químico— sirve como base para un **sistema inteligente de apoyo a la agroforestería silvopastoril regional**.
#
# **¿Por qué estos dominios son estratégicos para el silvopastoreo regenerativo en el sur de Chile?**
#
# - 🎵 **Sonidos de Animales**: Monitoreo del bienestar animal en sistemas silvopastoriles donde los animales interactúan con árboles, arbustos comestibles y pasturas, detectando estrés por sombra insuficiente, cambios dietarios o patrones de pastoreo regenerativo
# - 🌿 **Imágenes de Plantas**: Diagnóstico temprano de la salud del ecosistema integrado (árboles + arbustos + pasturas), evaluando simbiosis, competencia por nutrientes y regeneración del suelo en tiempo real mediante drones
# - 🥛 **Calidad de Leche**: Control automatizado que correlacione la composición nutricional de la leche con la diversidad dietaria proveniente de sistemas silvopastoriles (hojas, frutos, hierbas), optimizando la alimentación regenerativa
#
# **🌳 Enfoque Silvopastoril Regenerativo Específico:**
# - **Optimización de sombra natural** mediante análisis de patrones de copa arbórea y comportamiento animal
# - **Monitoreo de regeneración del suelo** a través de indicadores de biodiversidad vegetal y actividad biológica
# - **Gestión inteligente de pastoreo rotativo** que maximice la captura de carbono y la salud del ecosistema
# - **Integración nutricional** de árboles forrajeros, arbustos comestibles y praderas para optimizar producción y sostenibilidad
#
# Estos tres dominios convergen en un **ecosistema de aprendizaje autónomo silvopastoril**, donde los datos sensoriales se complementan para fortalecer la regeneración ecológica, eficiencia productiva y competitividad sustentable de la región.
#
# ## Objetivos del Proyecto
#
# ### Objetivo General
# Explorar y proponer problemas aplicables al **aprendizaje no supervisado** en el contexto del **silvopastoreo regenerativo del sur de Chile**, utilizando datasets reales y multidominio (imagen, audio y datos tabulares), para identificar patrones, anomalías y estructuras latentes que aporten valor directo en la toma de decisiones inteligentes para **sistemas agroforestales silvopastoriles**.
#
# ### Objetivos Específicos
#
# 1. **Analizar 10 datasets diversos** evaluándolos específicamente por su aplicabilidad al **silvopastoreo regenerativo** del sur de Chile
# 2. **Seleccionar tres datasets estratégicos** (*Animal Sounds*, *PlantVillage*, *Milk Quality*) con máxima relevancia para **agroforestería silvopastoril**, monitoreo ecosistémico y calidad nutricional regenerativa
# 3. **Proponer problemas concretos de silvopastoreo** que demuestren el potencial de ML no supervisado en integración de árboles, arbustos comestibles, pasturas y manejo animal regenerativo
# 4. **Aplicar técnicas avanzadas** (*K-Means*, *DBSCAN*, *GMM*, *HDBSCAN*) priorizando aquellas más adecuadas para sensores IoT silvopastoriles, drones de monitoreo ecosistémico y robótica regenerativa
# 5. **Diseñar métricas y herramientas** (*Python, Scikit-learn, TensorFlow, PyTorch*) que faciliten la futura integración en sistemas inteligentes de **silvopastoreo regenerativo** del sur de Chile, incluyendo monitoreo de regeneración del suelo, optimización de sombra arbórea y gestión del pastoreo rotativo

# %% [markdown]
# ## ⚙️ Configuración Inicial y Librerías
#
# En esta sección se importan las librerías esenciales para el análisis exploratorio de los datasets y la visualización de resultados.
# Incluye módulos de manipulación de datos, visualización y utilidades personalizadas que facilitan la presentación estructurada del proyecto.

# %%
# Librerías principales
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
from pathlib import Path
import warnings; warnings.filterwarnings('ignore')

# Utilidades de presentación (personalizadas)
from utils.presentation import show_section, show_subsection, show_list, print_kv, blank

# Configuración visual
plt.style.use('default'); sns.set_palette("husl")
plt.rcParams.update({'figure.figsize': (12, 8), 'font.size': 10})

print("✅ Librerías cargadas y entorno configurado.")
# Out:
# ✅ Librerías cargadas y entorno configurado.

# %% [markdown]
# ## 1. Presentación y Análisis de los 10 Datasets
#
# Esta sección presenta una **visión panorámica** de los 10 datasets seleccionados para el análisis de Machine Learning no supervisado
#
# ### 📋 **Tabla Resumen**
#
# La siguiente tabla presenta de manera sistemática cada dataset con sus características principales, aplicaciones en ML no supervisado y relevancia específica para nuestro contexto rural:

# %%
# Importar función desde el módulo de presentación
import importlib
import sys

# Recargar el módulo para obtener la nueva función
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import generate_datasets_summary_table

# Generar y mostrar la tabla resumen de datasets
df_summary = generate_datasets_summary_table()
# Out:
# 📋 TABLA RESUMEN DE LOS 10 DATASETS
# ...
# <style type="text/css">
# #T_c04e7 thead th {
#   background-color: #4C72B0;
#   color: white;
#   font-weight: bold;
# }
# #T_c04e7 tbody tr:nth-child(even) {
#   background-color: #f2f2f2;
# }
# #T_c04e7 tbody tr:nth-child(odd) {
#   background-color: white;
# }
# ...

# %% [markdown]
# # Dataset 1: Dairy Goods Sales Dataset
#
# ## Descripción
# Dataset de ventas de productos lácteos con registros transaccionales por fecha, tienda y categoría de producto (leche, queso, yogur). Permite estudiar patrones de demanda, estacionalidad y comportamiento de compra a nivel de producto y punto de venta.

# %%
# Análisis del Dairy Goods Sales Dataset
import importlib
import sys

# Recargar el módulo para obtener las correcciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_dairy_dataset

# Cargar dataset
dairy_df = pd.read_csv('Dairy Goods Sales Dataset/dairy_dataset.csv')

# Mostrar análisis completo
show_section("Dairy Goods Sales Dataset", emoji="🧀")
analyze_dairy_dataset(dairy_df)
# Out:
# 🧀 DAIRY GOODS SALES DATASET
# ...
#
#
# ✅ CARGA Y DESCRIPCIÓN DEL CONJUNTO DE DATOS
# - Filas × Columnas: 4,325 × 23
# - Uso de memoria: 3201.5 KB
#
# 📋 COLUMNAS DISPONIBLES
#    1. Location                       (object  ) - 15 valores únicos
#    2. Total Land Area (acres)        (float64 ) - continua valores únicos
#    3. Number of Cows                 (int64   ) - 91 valores únicos
#    4. Farm Size                      (object  ) - 3 valores únicos
#    5. Date                           (object  ) - 1278 valores únicos
#    6. Product ID                     (int64   ) - 10 valores únicos
#    7. Product Name                   (object  ) - 10 valores únicos
#    8. Brand                          (object  ) - 11 valores únicos
#    9. Quantity (liters/kg)           (float64 ) - continua valores únicos
#   10. Price per Unit                 (float64 ) - continua valores únicos
#   11. Total Value                    (float64 ) - continua valores únicos
# ...

# %% [markdown]
# ## Dataset 2: Animal Sounds Dataset - Análisis de Características
#
# ### 📊 **Descripción del Dataset**
# Dataset de **sonidos de animales** que incluye múltiples especies (león, burro, vaca, gato, perro, oveja, rana, pájaro, pollo, mono) con archivos de audio en formato WAV organizados por carpetas de especies. Contiene grabaciones de vocalizaciones naturales que permiten estudiar patrones acústicos distintivos, identificar especies mediante características espectrales y analizar comportamientos comunicativos de forma automatizada sin supervisión previa.
#
# ### 🌍 **Problemas del Mundo Real**
# Con este dataset y modelos de aprendizaje no supervisado se pueden resolver problemas críticos como: **monitoreo de bienestar animal** en granjas detectando patrones de estrés o enfermedad a través de vocalizaciones anómalas, **sistemas de alerta temprana** para identificar comportamientos agresivos o de apareamiento, **clasificación automática de especies** en estudios de biodiversidad sin necesidad de etiquetado manual, **detección de intrusos** en áreas protegidas mediante análisis de sonidos ambientales, y **optimización de manejo ganadero** identificando patrones de comunicación que indican necesidades específicas (alimentación, agua, refugio).
#
# ### 🧠 **Técnicas de ML No Supervisado Propuestas**
# - **DBSCAN**: Ideal para detectar agrupaciones de vocalizaciones por densidad sin definir número de clusters a priori, especialmente útil para identificar sonidos anómalos o especies raras como outliers naturales
# - **K-Means + MFCC**: Clustering de características espectrales (coeficientes cepstrales) para agrupar vocalizaciones similares; K-Means funciona bien con vectores MFCC de dimensionalidad fija y permite interpretación directa de centroides como "vocalizaciones típicas"
# - **PCA + t-SNE**: Reducción dimensional de espectrogramas para visualización de estructura latente y exploración de relaciones inter-especies; PCA captura varianza principal mientras t-SNE revela agrupaciones no lineales complejas
# - **Autoencoders Variacionales**: Aprendizaje de representaciones comprimidas de audio que capturen características esenciales de cada especie, útil para generar vocalizaciones sintéticas y detectar anomalías por reconstrucción
#
# ### ⚠️ **Desafíos Potenciales**
# - **Calidad de grabación variable**: Diferencias en equipos, distancias y condiciones ambientales crean ruido de fondo inconsistente que puede afectar extracción de características
# - **Desbalance entre especies**: Algunas especies pueden tener significativamente más grabaciones que otras, sesgando algoritmos hacia clases mayoritarias
# - **Variabilidad intra-especie**: Diferencias por edad, género, contexto emocional (hambre, miedo, apareamiento) crean alta varianza dentro de cada especie
# - **Complejidad computacional**: Procesamiento de audio requiere extracción de características costosa (FFT, MFCC, espectrogramas) y almacenamiento de matrices de alta dimensionalidad
# - **Duración temporal variable**: Vocalizaciones de diferentes longitudes requieren normalización o técnicas de secuencia (padding, truncamiento) antes del clustering
# - **Solapamiento espectral**: Especies con rangos de frecuencia similares pueden generar clusters ambiguos difíciles de separar sin supervisión
#
# ### 🎯 **Relevancia en ML No Supervisado**
# - **Clustering acústico**: Agrupar sonidos por similitudes espectrales
# - **Detección de patrones**: Identificar características distintivas sin etiquetas previas
# - **Reducción de dimensionalidad**: Extraer componentes principales del espectro de audio
# - **Detección de anomalías**: Identificar vocalizaciones atípicas o errores de grabación

# %%
# Análisis del Animal Sounds Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import analyze_animal_sounds_dataset
from pathlib import Path

dataset_path = Path("Animal Sound Dataset")
analyze_animal_sounds_dataset(dataset_path)
# Out:
# 🐾 ANIMAL SOUNDS DATASET
# ...
#
#
# 📊 DESCRIPCIÓN DEL DATASET
# - Número de categorías de animales: 13
# - Total de archivos de audio: 875
#
# 📦 DISTRIBUCIÓN POR ESPECIES
# - León: 45 archivos
# - Burro: 25 archivos
# - Vaca: 75 archivos
# - Gato (Parte 1): 100 archivos
# - Gato (Parte 2): 100 archivos
# - Perro (Parte 1): 100 archivos
# - Perro (Parte 2): 100 archivos
# - Oveja: 40 archivos
# - Rana: 35 archivos
# - Pájaro (Parte 1): 100 archivos
# - Pájaro (Parte 2): 100 archivos
# - Mono: 25 archivos
# - Pollo: 30 archivos
#
# 🔊 🎵 EJEMPLOS DE SONIDOS POR ESPECIE
# 📌 Especies disponibles en el dataset:
#
#    1. León (Aslan)
#    2. Burro (Esek)
#    3. Vaca (Inek)
#    4. Gato (Parte 1) (Kedi-Part1)
#    5. Gato (Parte 2) (Kedi-Part2)
#    6. Perro (Parte 1) (Kopek-Part1)
#    7. Perro (Parte 2) (Kopek-Part2)
#    8. Oveja (Koyun)
#    9. Rana (Kurbaga)
#    10. Pájaro (Parte 1) (Kus-Part1)
#    11. Pájaro (Parte 2) (Kus-Part2)
#    12. Mono (Maymun)
#    13. Pollo (Tavuk)
#
# ...

# %%
# Reproducción interactiva de sonidos de animales
import importlib
import sys

# Recargar el módulo para obtener la nueva función
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import play_animal_sounds_interactive
from pathlib import Path

# Ejecutar función de reproducción interactiva
dataset_path = Path("Animal Sound Dataset")
play_animal_sounds_interactive(dataset_path)
# Out:
# 🎵 REPRODUCCIÓN DE SONIDOS DE ANIMALES
# ...
#
# 🎵 **REPRODUCIENDO SONIDO ALEATORIO**
# ...
# 🐾 **Animal**: Perro (Parte 2)
# 📁 **Archivo**: dog_144.wav
# ...
# 📊 **Características del audio**:
#    • Duración: 8.52 segundos
#    • Frecuencia de muestreo: 11,025 Hz
#    • Número de muestras: 93,968
# 🔊 **Reproduciendo audio...**
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ✅ **Audio reproducido exitosamente**

# %% [markdown]
# ## Dataset 3: Customer Personality Analysis - Análisis de Características
#
# ### Descripción General
# Dataset de **análisis de personalidad de clientes** que incluye información demográfica, comportamiento de compra y características psicográficas. Esencial para estrategias de marketing personalizado.
#
# ### Relevancia en ML No Supervisado
# - **Segmentación de Clientes**: Identificar perfiles naturales sin categorías predefinidas
# - **Análisis de Comportamiento**: Descubrir patrones de compra ocultos
# - **Reducción Dimensional**: Identificar factores clave que definen la personalidad del consumidor

# %%
# Análisis del Customer Personality Analysis Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_customer_personality_dataset

# Cargar dataset (el archivo usa tabulaciones como separador)
customer_df = pd.read_csv('Customer personality Analysis/marketing_campaign.csv', sep='\t')

# Mostrar análisis completo
show_section("Customer Personality Analysis Dataset", emoji="🧑🏻‍🤝‍🧑🏽")
analyze_customer_personality_dataset(customer_df)
# Out:
# 🧑🏻‍🤝‍🧑🏽 CUSTOMER PERSONALITY ANALYSIS DATASET
# ...
#
#
# ✅ CARGA Y DESCRIPCIÓN DEL CONJUNTO DE DATOS
# - Filas × Columnas: 2,240 × 29
# - Uso de memoria: 883.0 KB
#
# 📋 COLUMNAS DISPONIBLES
#    1. ID                             (int64   ) - 2240 valores únicos
#    2. Year_Birth                     (int64   ) - 59 valores únicos
#    3. Education                      (object  ) - 5 valores únicos
#    4. Marital_Status                 (object  ) - 8 valores únicos
#    5. Income                         (float64 ) - continua valores únicos
#    6. Kidhome                        (int64   ) - 3 valores únicos
#    7. Teenhome                       (int64   ) - 3 valores únicos
#    8. Dt_Customer                    (object  ) - 663 valores únicos
#    9. Recency                        (int64   ) - 100 valores únicos
#   10. MntWines                       (int64   ) - 776 valores únicos
#   11. MntFruits                      (int64   ) - 158 valores únicos
# ...

# %% [markdown]
# ## Dataset 4: News Category Dataset - Análisis de Características
#
# ### Descripción General
# Dataset de **categorización de noticias** que contiene títulos, descripciones y metadatos de artículos periodísticos de HuffPost (2012-2022). Fundamental para el análisis de contenido mediático y comprensión de tendencias informativas.
#
# ### Relevancia en ML No Supervisado
# - **Topic Modeling**: Descubrir temas emergentes sin categorías predefinidas
# - **Clustering Semántico**: Agrupar noticias por contenido similar
# - **Análisis de Tendencias**: Identificar patrones temporales en cobertura mediática
# - **Detección de Anomalías**: Encontrar noticias atípicas o eventos excepcionales

# %%
# Análisis del News Category Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_news_category_dataset

# Mostrar análisis teórico basado en fuente web
show_section("News Category Dataset", emoji="📰")
analyze_news_category_dataset()
# Out:
# 📰 NEWS CATEGORY DATASET
# ...
#
#
# 🌐 ANÁLISIS BASADO EN FUENTE WEB
# - URL de origen: https://www.kaggle.com/datasets/rmisra/news-category-dataset
# - Estado del dataset: No disponible localmente - Análisis teórico
#
# 📊 CARACTERÍSTICAS ESPERADAS DEL DATASET
# - Tamaño estimado: ~210,000 artículos de noticias (HuffPost)
# - Formato: JSON
# - Período temporal: 2012-2022
# - Variables principales: headline, short_description, category, authors, date
#
# 📋 ESTRUCTURA DE DATOS ESPERADA
#   1. headline (título del artículo)
#   2. short_description (descripción breve)
#   3. category (categoría de noticia)
#   4. authors (autores)
#   5. date (fecha de publicación)
#   6. link (enlace web)
#
# 📰 ANÁLISIS DE DOMINIO
# - Diversidad temática: Política, entretenimiento, deportes, tecnología, mundo, etc.
# - Longitud promedio titular: ~50 caracteres
# - Longitud promedio descripción: ~200 caracteres
# - Idioma: Inglés
#
# 🎯 POTENCIAL PARA ML NO SUPERVISADO
# ...

# %% [markdown]
# ## Dataset 5: Global Coffee Health Dataset - Análisis de Características
#
# ### Descripción General
# Dataset de **consumo de café y salud global** que correlaciona patrones de consumo de café con indicadores de salud poblacional por países (2000-2020). Esencial para estudios epidemiológicos y análisis de políticas de salud pública.
#
# ### Relevancia en ML No Supervisado
# - **Clustering Geográfico**: Identificar regiones con patrones similares de consumo-salud
# - **Detección de Correlaciones**: Descubrir relaciones no evidentes entre café y bienestar
# - **Segmentación Poblacional**: Agrupar países por perfiles de salud y consumo
# - **Análisis de Outliers**: Identificar países con patrones únicos o excepcionales

# %%
# Análisis del Global Coffee Health Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_coffee_health_dataset

# Mostrar análisis teórico basado en fuente web
show_section("Global Coffee Health Dataset", emoji="☕")
analyze_coffee_health_dataset()
# Out:
# ☕ GLOBAL COFFEE HEALTH DATASET
# ...
#
#
# 🌐 ANÁLISIS BASADO EN FUENTE WEB
# - URL de origen: https://www.kaggle.com/datasets/uom190346a/global-coffee-health-dataset
# - Estado del dataset: No disponible localmente - Análisis teórico
#
# 📊 CARACTERÍSTICAS ESPERADAS DEL DATASET
# - Alcance geográfico: ~180+ países/regiones globales
# - Período temporal: Datos longitudinales 2000-2020
# - Tipo de datos: Numérico/geográfico con indicadores de salud
# - Variables principales: consumo per cápita, esperanza de vida, indicadores socioeconómicos
#
# ☕ VARIABLES ESPERADAS POR CATEGORÍA
#   1. Coffee_Consumption_Per_Capita (kg/año)
#   2. Life_Expectancy (años)
#   3. Heart_Disease_Rate (%)
#   4. Diabetes_Prevalence (%)
#   5. GDP_Per_Capita (USD)
#   6. Healthcare_Index (0-100)
#
# 🗺️ COBERTURA REGIONAL ESPERADA
# - Regiones incluidas: Europa, América, Asia, África, Oceanía
# - Variabilidad cultural: Diferentes patrones de consumo por región
# ...

# %% [markdown]
# ## Dataset 6: Credit Card Customer - Análisis de Características
#
# ### Descripción General
# Dataset de **clientes de tarjetas de crédito** que incluye información transaccional, demográfica y comportamental. Fundamental para la gestión de riesgo crediticio y detección de fraudes en servicios financieros.
#
# ### Relevancia en ML No Supervisado
# - **Detección de Fraudes**: Identificar patrones anómalos en transacciones
# - **Segmentación Crediticia**: Agrupar clientes por perfiles de riesgo
# - **Análisis Comportamental**: Descubrir patrones de uso no evidentes
# - **Perfilado Automático**: Crear segmentos para productos financieros

# %%
# Análisis del Credit Card Customer Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_credit_card_dataset

# Mostrar análisis teórico basado en fuente web
show_section("Credit Card Customer Dataset", emoji="💳")
analyze_credit_card_dataset()
# Out:
# 💳 CREDIT CARD CUSTOMER DATASET
# ...
#
#
# 🌐 ANÁLISIS BASADO EN FUENTE WEB
# - URL de origen: https://www.kaggle.com/datasets/sakshigoyal7/credit-card-customers
# - Estado del dataset: No disponible localmente - Análisis teórico
#
# 📊 CARACTERÍSTICAS ESPERADAS DEL DATASET
# - Tamaño estimado: ~10,000 registros de clientes
# - Variables esperadas: 20+ columnas financieras y demográficas
# - Dominio: Servicios financieros - Gestión de riesgo crediticio
#
# 💳 VARIABLES FINANCIERAS CLAVE ESPERADAS
#   1. Credit_Limit (límite de crédito autorizado)
#   2. Total_Revolving_Bal (balance rotativo actual)
#   3. Total_Trans_Amt (monto total de transacciones)
#   4. Total_Trans_Ct (cantidad de transacciones)
#   5. Avg_Utilization_Ratio (ratio de utilización promedio)
#   6. Customer_Age (edad del cliente)
#   7. Income_Category (categoría de ingresos)
#   8. Card_Category (tipo de tarjeta)
#
# 👥 PERFILES DE CLIENTES ESPERADOS
# - Segmentos demográficos: Edad, género, estado civil, educación
# ...

# %% [markdown]
# ## Dataset 7: Sleep Health and Lifestyle - Análisis de Características
#
# ### Descripción General
# Dataset de **salud del sueño y estilo de vida** que correlaciona patrones de sueño con variables de salud física y mental. Esencial para el desarrollo de intervenciones personalizadas en medicina del sueño y bienestar.
#
# ### Relevancia en ML No Supervisado
# - **Clustering de Patrones**: Identificar cronotipos y perfiles de sueño naturales
# - **Detección de Trastornos**: Encontrar anomalías indicativas de patologías del sueño
# - **Factores de Riesgo**: Descubrir combinaciones no evidentes que afectan la calidad del sueño
# - **Medicina Personalizada**: Crear perfiles de bienestar para intervenciones individualizadas

# %%
# Análisis del Sleep Health and Lifestyle Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_sleep_health_dataset

# Mostrar análisis teórico basado en fuente web
show_section("Sleep Health and Lifestyle Dataset", emoji="😴")
analyze_sleep_health_dataset()
# Out:
# 😴 SLEEP HEALTH AND LIFESTYLE DATASET
# ...
#
#
# 🌐 ANÁLISIS BASADO EN FUENTE WEB
# - URL de origen: https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# - Estado del dataset: No disponible localmente - Análisis teórico
#
# 📊 CARACTERÍSTICAS ESPERADAS DEL DATASET
# - Tamaño estimado: ~400 registros de individuos
# - Variables esperadas: 13 columnas (sueño, físicas, estilo de vida)
# - Dominio: Medicina del sueño y bienestar personal
#
# 😴 VARIABLES DE SUEÑO Y SALUD ESPERADAS
#   1. Sleep_Duration (horas de sueño por noche)
#   2. Quality_of_Sleep (calidad percibida 1-10)
#   3. Physical_Activity_Level (minutos ejercicio/día)
#   4. Stress_Level (nivel de estrés 1-10)
#   5. BMI_Category (categoría índice masa corporal)
#   6. Heart_Rate (frecuencia cardíaca en bpm)
#   7. Daily_Steps (pasos diarios promedio)
#   8. Sleep_Disorder (trastorno del sueño diagnosticado)
#
# 🛌 PERFILES DE SUEÑO ESPERADOS
# - Cronotipos: Mañaneros, nocturnos, intermedios
# ...

# %% [markdown]
# ## Dataset 8: Wholesale Customers Dataset - Análisis de Características
#
# ### Descripción General
# Dataset de **clientes mayoristas** que registra compras anuales por categorías de productos. Clásico en el análisis de segmentación B2B y optimización de cadenas de suministro comercial.
#
# ### Relevancia en ML No Supervisado
# - **Segmentación B2B**: Identificar tipos de clientes mayoristas por patrones de compra
# - **Optimización de Inventario**: Descubrir correlaciones entre categorías de productos
# - **Estrategias Comerciales**: Agrupar clientes para ofertas personalizadas
# - **Detección de Nichos**: Identificar segmentos de mercado especializado

# %%
# Análisis del Wholesale Customers Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_wholesale_customers_dataset

# Mostrar análisis teórico basado en fuente web
show_section("Wholesale Customers Dataset", emoji="📦")
analyze_wholesale_customers_dataset()
# Out:
# 📦 WHOLESALE CUSTOMERS DATASET
# ...
#
#
# 🌐 ANÁLISIS BASADO EN FUENTE WEB
# - URL de origen: https://www.kaggle.com/datasets/binovi/wholesale-customers-data-set
# - Estado del dataset: No disponible localmente - Análisis teórico
#
# 📊 CARACTERÍSTICAS ESPERADAS DEL DATASET
# - Tamaño: 440 clientes mayoristas
# - Origen: UCI Machine Learning Repository (dataset clásico)
# - Sector: Distribución B2B de productos de consumo masivo
# - Variables: 8 columnas (Channel, Region + 6 categorías de productos)
#
# 📦 CATEGORÍAS DE PRODUCTOS ESPERADAS
#   1. Fresh (productos frescos: frutas, verduras, carnes)
#   2. Milk (productos lácteos y derivados)
#   3. Grocery (comestibles secos y enlatados)
#   4. Frozen (productos congelados)
#   5. Detergents_Paper (productos de limpieza y papel)
#   6. Delicatessen (productos gourmet y especialidades)
#
# 🏢 SEGMENTACIÓN COMERCIAL ESPERADA
# - Canales de venta: Horeca (hoteles/restaurantes) vs Retail (minoristas)
# ...

# %% [markdown]
# ## Dataset 9: PlantVillage - Análisis de Características
#
# ### 📊 **Descripción del Dataset**
# Dataset PlantVillage disponible en Kaggle, compuesto por ≈ 54.305 imágenes RGB de hojas de 14 especies de plantas (tomate, papa, maíz, manzana, uva, etc.), organizadas en 38 clases que combinan especie + condición de salud (sanas y con diferentes enfermedades). Las imágenes están tomadas en condiciones controladas con fondo uniforme, diseñadas originalmente para entrenar modelos de diagnóstico vegetal automatizado mediante visión por computador, pero ideales para técnicas no supervisadas de agrupamiento visual y detección de patrones.
#
# ### 🌍 **Problemas del Mundo Real**
# Con este dataset y aprendizaje no supervisado se pueden abordar problemas críticos como: **detección temprana de enfermedades vegetales** mediante clustering de características visuales antes de síntomas evidentes, **sistemas de monitoreo agrícola automatizado** con drones que identifiquen zonas problemáticas sin supervisión, **clasificación de severidad de enfermedades** agrupando imágenes por grados de deterioro, **descubrimiento de nuevas patologías** detectando clusters anómalos no catalogados previamente, **optimización de tratamientos** identificando patrones visuales que respondan mejor a diferentes intervenciones, y **control de calidad en procesamiento alimentario** detectando productos defectuosos mediante análisis no supervisado de características visuales.
#
# ### 🧠 **Técnicas de ML No Supervisado Propuestas**
# - **K-Means + CNN Features**: Extracción de embeddings con redes pre-entrenadas (ResNet, EfficientNet) seguida de clustering K-Means; las CNN capturan características visuales complejas mientras K-Means agrupa por similitudes, ideal para identificar patrones de enfermedades
# - **HDBSCAN**: Clustering jerárquico basado en densidad que maneja clusters de tamaños variables y detecta outliers naturalmente; perfecto para identificar enfermedades raras o nuevas patologías como anomalías
# - **UMAP + Clustering**: Reducción dimensional no lineal que preserva estructura local y global, seguida de clustering; UMAP visualiza relaciones entre especies y enfermedades mientras mantiene separabilidad
# - **Autoencoders Convolucionales**: Aprendizaje de representaciones comprimidas de imágenes que capturen características esenciales; útil para detectar anomalías por error de reconstrucción y generar mapas de características relevantes
#
# ### ⚠️ **Desafíos Potenciales**
# - **Condiciones controladas vs. campo**: Dataset tomado en laboratorio puede no generalizar bien a condiciones reales de campo con variaciones de iluminación, ángulos y fondos complejos
# - **Desbalance entre clases**: Algunas enfermedades tienen significativamente más muestras que otras, sesgando algoritmos hacia patologías comunes
# - **Variabilidad intra-clase alta**: Misma enfermedad en diferentes estadios de desarrollo crea alta varianza dentro de clusters, dificultando separación clara
# - **Complejidad computacional**: Procesamiento de 54K+ imágenes RGB requiere recursos computacionales considerables para extracción de características CNN y clustering
# - **Solapamiento visual entre enfermedades**: Síntomas similares entre diferentes patologías pueden crear clusters ambiguos difíciles de interpretar sin conocimiento experto
# - **Dependencia de calidad de imagen**: Resolución, enfoque y condiciones de captura inconsistentes pueden afectar extracción confiable de características
# - **Escalabilidad temporal**: Apariencia de enfermedades cambia con estaciones y condiciones climáticas, requiriendo re-entrenamiento periódico
#
# ### 🎯 **Relevancia en ML No Supervisado**
# - **Agrupamiento de patrones visuales**: Descubrir similitudes entre hojas de diferentes especies o enfermedades
# - **Detección de anomalías**: Identificar hojas con síntomas poco comunes o enfermedades emergentes
# - **Visualización de estructura latente**: Usar embeddings para explorar relaciones entre clases sin supervisión directa
# - **Preprocesamiento para etiquetado activo**: Agrupar hojas similares y reducir costos de anotación manual

# %%
# Análisis del PlantVillage Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_plantvillage_dataset

# Ruta del dataset
dataset_path = "PlantVillage"

# Mostrar análisis completo con EDA avanzado
show_section("PlantVillage Dataset", emoji="🌿")
analyze_plantvillage_dataset(dataset_path)
# Out:
# 🌿 PLANTVILLAGE DATASET
# ...
#
#
# ✅ CARGA Y DESCRIPCIÓN DEL CONJUNTO DE DATOS
# - Ubicación: PlantVillage
# - Clases detectadas: 15
# - Total de imágenes: 20,638
# - Promedio por clase: 1375.9
# - Desviación estándar: 744.5
# - Tamaño estimado: 351.4 MB
#
# 📊 ANÁLISIS DE DISTRIBUCIÓN POR CLASES
# - Tipos de plantas: 2
# - Condiciones detectadas: 5
# - Distribución de condiciones: {'other': 14420, 'healthy': 3221, 'Early_blight': 1000, 'Late_blight': 1000, 'Bacterial_spot': 997}
#
# 🎨 EDA VISUAL
# 📐 ESTADÍSTICAS TÉCNICAS
# - Resolución promedio: 256 px (equiv.)
# - Brillo promedio: 117.6
# - Aspect ratio promedio: 1.00
# - Variabilidad de tamaño: CV = 0.0%
#
# 🎯 POTENCIAL PARA ML NO SUPERVISADO
# - Clustering visual por características de color y textura
# - Detección de anomalías en hojas con patrones atípicos
# - Reducción dimensional con autoencoders para embeddings de imágenes
# - Segmentación no supervisada por severidad de enfermedad
# ...

# %% [markdown]
# ## Dataset 10: Milk Quality Dataset - Análisis de Características
#
# ### 📊 **Descripción del Dataset**
# Dataset de **calidad de la leche** basado en parámetros fisicoquímicos que incluye variables críticas como pH (acidez), temperatura, grasa, turbidez, color, y otros indicadores de frescura y contaminación bacteriana. Cada muestra está caracterizada por múltiples mediciones numéricas que determinan la calidad final del producto lácteo, siendo fundamental para la industria alimentaria y el control de calidad automático en líneas de producción donde la detección temprana de problemas puede prevenir pérdidas económicas significativas.
#
# ### 🌍 **Problemas del Mundo Real**
# Con este dataset y técnicas no supervisadas se pueden resolver problemas industriales críticos como: **sistemas de control de calidad automatizado** que detecten lotes defectuosos sin supervisión previa, **alerta temprana de contaminación bacteriana** mediante detección de patrones anómalos en parámetros fisicoquímicos, **optimización de procesos de pasteurización** identificando condiciones óptimas a través de clustering de muestras exitosas, **clasificación automática por grados de calidad** (premium, estándar, descarte) basada en agrupamientos naturales, **detección de adulteraciones** identificando perfiles químicos inconsistentes con leche pura, y **predicción de vida útil** mediante análisis de patrones de deterioro sin necesidad de etiquetas temporales.
#
# ### 🧠 **Técnicas de ML No Supervisado Propuestas**
# - **K-Means**: Ideal para datos numéricos tabulares como parámetros fisicoquímicos; permite crear categorías automáticas de calidad (alta/media/baja) y identificar centroides interpretables como "perfiles de calidad tipo"
# - **Isolation Forest**: Técnica especializada en detección de anomalías para identificar muestras con combinaciones atípicas de parámetros que indiquen contaminación o adulteración; funciona bien con datos multivariados numéricos
# - **DBSCAN**: Clustering basado en densidad que identifica grupos naturales de calidad similar mientras detecta outliers; útil cuando no se conoce a priori cuántos niveles de calidad existen
# - **PCA + Clustering**: Reducción dimensional para identificar combinaciones críticas de parámetros que más influyen en calidad, seguida de clustering en espacio reducido para mejor interpretabilidad y visualización
#
# ### ⚠️ **Desafíos Potenciales**
# - **Escalas variables**: Parámetros como pH (0-14), temperatura (°C), y grasa (%) tienen escalas diferentes que requieren normalización cuidadosa para evitar dominancia de variables con rangos mayores
# - **Correlaciones entre variables**: pH, acidez y temperatura están naturalmente correlacionados, creando redundancia que puede sesgar clustering hacia estas dimensiones
# - **Outliers legítimos vs. errores**: Distinguir entre muestras genuinamente anómalas (contaminación real) y errores de medición o calibración de equipos
# - **Datos faltantes**: Sensores defectuosos o procesos de medición incompletos pueden generar valores faltantes que requieren imputación cuidadosa
# - **Variabilidad estacional**: Calidad de leche varía por factores externos (alimentación animal, clima, época del año) creando clusters temporalmente dependientes
# - **Desbalance de calidad**: Mayoría de muestras probablemente sean de calidad aceptable, con pocas muestras defectuosas, dificultando detección de patrones anómalos
# - **Interpretabilidad industrial**: Clusters deben ser explicables para operadores de planta que necesitan tomar decisiones de proceso basadas en resultados del algoritmo
#
# ### 🎯 **Relevancia en ML No Supervisado**
# - **Control de Calidad**: Sistema de clustering para clasificación automática de calidad
# - **Detección de Contaminación**: Identificar muestras con propiedades anómalas o bacterianas
# - **Reducción de Dimensionalidad**: Identificar los factores más críticos en la calidad
# - **Optimización de Procesos**: Descubrir factores críticos de calidad sin supervisión

# %%
# Análisis del Milk Quality Dataset
import importlib
import sys

# Recargar el módulo para obtener las nuevas funciones
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import show_section, analyze_milk_quality_dataset

# Ruta del dataset
file_path = 'Milk Quality Dataset/milknew.csv'

# Mostrar análisis completo con EDA avanzado
show_section("Milk Quality Dataset", emoji="🥛")
analyze_milk_quality_dataset(file_path)
# Out:
# 🥛 MILK QUALITY DATASET
# ...
#
#
# ✅ CARGA Y DESCRIPCIÓN DEL CONJUNTO DE DATOS
# - Ubicación: Milk Quality Dataset/milknew.csv
# - Tamaño: 1,059 filas × 8 columnas
# - Uso de memoria: 121.4 KB
#
# 📋 COLUMNAS DISPONIBLES
#    1. pH                        (float64 ) - continua valores únicos
#    2. Temprature                (int64   ) - 17 valores únicos
#    3. Taste                     (int64   ) - 2 valores únicos
#    4. Odor                      (int64   ) - 2 valores únicos
#    5. Fat                       (int64   ) - 2 valores únicos
#    6. Turbidity                 (int64   ) - 2 valores únicos
#    7. Colour                    (int64   ) - 9 valores únicos
#    8. Grade                     (object  ) - 3 valores únicos
#
# 📈 ANÁLISIS ESTADÍSTICO
# - Variables numéricas: 7
# - Variables categóricas: 1
#   * pH: μ=6.63 (±1.40), rango=[3.00, 9.50]
#   * Temprature: μ=44.23 (±10.10), rango=[34.00, 90.00]
#   * Taste: μ=0.55 (±0.50), rango=[0.00, 1.00]
# ...

# %% [markdown]
# ## 2. Evaluación Comparativa de los 10 Datasets
#
# ### Contexto para Inteligencia Rural del Sur de Chile
#
# Para nuestro **objetivo principal** de desarrollar una inteligencia general orientada a la economía circular en el sur de Chile, que sea capaz de:
#
# - 🐄 **Monitoreo ganadero**: Supervisar bosques comestibles para vacas lecheras y ganado
# - 🥛 **Control de calidad láctea**: Evaluar calidad de la leche automáticamente
# - 🔊 **Detección comportamental**: Detectar comportamientos mediante señales auditivas con sensores
# - 🤖 **Innovación robótica**: Integración con sistemas automatizados de campo
#
# Es fundamental seleccionar datasets que no solo demuestren técnicas de ML no supervisado, sino que **contribuyan directamente** a este ecosistema inteligente rural.
#
# ### Criterios de Evaluación Contextualizados
#
# Los datasets serán evaluados considerando su **relevancia específica** para el contexto del sur de Chile:
#
# 1. **Diversidad de Datos** (15%): Variedad en tipos de datos y estructura técnica
# 2. **Potencial Clustering** (20%): Capacidad para generar agrupamientos significativos
# 3. **Relevancia e Impacto** (35%): Aplicabilidad directa en contexto rural sur de Chile
# 4. **Disponibilidad** (15%): Acceso real garantizado a los datos
# 5. **Complementariedad** (15%): Sinergia con ecosistema rural inteligente
#
# **Nota**: Se prioriza la **relevancia e impacto** (35%) por ser fundamental para nuestro objetivo de inteligencia aplicada al sur de Chile.

# %%
# Evaluación comparativa de los datasets usando función del módulo presentation
import importlib
import sys

# Recargar el módulo para obtener la nueva función
if 'utils.presentation' in sys.modules:
    importlib.reload(sys.modules['utils.presentation'])

from utils.presentation import evaluate_datasets_comparative

# Ejecutar evaluación comparativa contextualizada
df_evaluacion = evaluate_datasets_comparative()

print(f"\n🎯 Evaluación completada para {len(df_evaluacion)} datasets")
print(f"📊 Ponderación aplicada: Relevancia Rural (35%) + Potencial Clustering (20%) + otros criterios")
print(f"🌱 Contexto: Inteligencia para economía circular en el sur de Chile")
# Out:
# 📊 EVALUACIÓN COMPARATIVA DE DATASETS
# ...
#
# 🎯 Criterios de Evaluación para Inteligencia Rural del Sur de Chile:
#    • Diversidad de Datos (15%): Variedad en estructura y tipos
#    • Potencial Clustering (20%): Capacidad de agrupamientos significativos
#    • Relevancia e Impacto (35%): Aplicabilidad directa en contexto rural
#    • Disponibilidad (15%): Acceso garantizado a los datos
#    • Complementariedad (15%): Sinergia con ecosistema inteligente
#    No.               Dataset  Diversidad_Datos  Potencial_Clustering  \
# 1    2         Animal Sounds                 9                     9
# 8    9          PlantVillage                 9                     8
# 9   10          Milk Quality                 8                     8
# 2    3  Customer Personality                 8                     8
# 7    8   Wholesale Customers                 6                     8
# 4    5         Coffee Health                 7                     7
# ...

# %% [markdown]
# ## 3. Datasets Seleccionados y Justificación Metodológica
#
# ### 🏆 Selección Final Basada en Evaluación Contextualizada
#
# Basándose en la evaluación comparativa anterior, los **3 datasets seleccionados** son:
#
# 1. **🎵 Animal Sounds Dataset** - Puntuación: 9.0 - **🌟 ALTA RELEVANCIA RURAL**
# 2. **🌿 PlantVillage Dataset** - Puntuación: 8.8 - **🌟 ALTA RELEVANCIA RURAL**
# 3. **🥛 Milk Quality Dataset** - Puntuación: 8.8 - **🌟 ALTA RELEVANCIA RURAL**
#
# Esta selección garantiza **máxima diversidad técnica** (Audio + Visual + Numérico) y **aplicabilidad directa** en el contexto agropecuario del sur de Chile.
#
# ---
#
# ### 📋 Justificación Metodológica del Proyecto
#
# Con base en todo el análisis realizado, ahora podemos fundamentar sólidamente las decisiones metodológicas de nuestro proyecto de **Inteligencia Rural para el Sur de Chile**:

# %% [markdown]
# ## 4. Propuesta Metodológica Fundamentada
#
# ### 🎯 **¿Qué problema concreto resolverás? ¿Por qué es relevante?**
#
# **Problema Central**: Desarrollar una **inteligencia general orientada a la economía circular** para el contexto del **silvopastoreo regenerativo del sur de Chile**, capaz de:
#
# - 🌳 **Sistemas Silvopastoriles Inteligentes**: Monitoreo automatizado de **agroforestería silvopastoril** integrando árboles, arbustos comestibles y pasturas para optimización de nutrientes, sombra natural y regeneración del suelo mediante sensores IoT y drones
# - 🥛 **Evaluar la calidad de la leche regenerativa** correlacionando parámetros fisicoquímicos con la diversidad dietaria proveniente de sistemas silvopastoriles (hojas, frutos, hierbas, pasturas enriquecidas)
# - 🔊 **Detectar comportamientos y bienestar animal** en ambientes silvopastoriles mediante señales auditivas, identificando patrones de pastoreo, interacción con árboles y estrés por manejo regenerativo
# - 🤖 **Integración con robótica de pastoreo regenerativo** para automatización de rotación inteligente, manejo de sombra arbórea y optimización del ecosistema integrado
# - 🌱 **Monitoreo de regeneración del suelo y captura de carbono** mediante análisis de patrones de crecimiento, biodiversidad y salud del ecosistema silvopastoril
#
# **Relevancia Comprobada para el Silvopastoreo Regenerativo**:
# - **Económica**: El sur de Chile lidera la producción láctea nacional (>60%) y tiene potencial único para sistemas silvopastoriles por su clima temperado lluvioso
# - **Ecológica**: La **agroforestería silvopastoril** puede capturar 10-50 ton CO₂/ha/año mientras mantiene productividad, clave para compromisos de carbono neutralidad
# - **Tecnológica**: Gap específico en digitalización de sistemas regenerativos requiere IA especializada en ecosistemas integrados árbol-animal-suelo
# - **Social**: Mejora condiciones de bienestar animal, diversificación de ingresos (madera, frutos, servicios ecosistémicos) y resiliencia climática
#
# **🌳 Plan Técnico Realista para el Sur de Chile:**
#
# **Fase 1 - Sistemas de Referencia** (6 meses):
# - Establecer parcelas piloto en predios de Los Ríos/Los Lagos con especies nativas forrajeras:
#   - **Árboles**: Raulí (Nothofagus alpina), Avellano chileno (Gevuina avellana), Maqui (Aristotelia chilensis)
#   - **Arbustos**: Rosa mosqueta (Rosa rubiginosa), Murta (Ugni molinae), Arrayán (Luma apiculata)
#   - **Pasturas**: Ballica perenne + trébol blanco + hierbas nativas
#
# **Fase 2 - Sensórica Silvopastoril** (6 meses):
# - Implementar red IoT específica para silvopastoreo:
#   - Sensores de humedad de suelo bajo árboles vs pasturas abiertas
#   - Microfonos de campo para vocalizaciones en sombra vs sol
#   - Cámaras de dron para mapeo de cobertura arbórea y comportamiento animal
#   - Estaciones meteorológicas para microclimas árbol-pastura
#
# **Fase 3 - ML Silvopastoril** (12 meses):
# - Desarrollar algoritmos no supervisados específicos para:
#   - Clustering de zonas óptimas de sombra-pastura-agua mediante HDBSCAN
#   - Detección de patrones de pastoreo regenerativo con DBSCAN temporal
#   - Análisis de calidad láctea correlacionada con diversidad dietaria (K-Means + GMM)
#   - Predicción de regeneración del suelo mediante análisis de imágenes multiespectrales
#
# ---
#
# ### 🧠 **¿Qué tipo de modelos de aprendizaje no supervisado usarás? (2 vistos + 2 no vistos en clase)**
#
# **Algoritmos Vistos en Clase - Adaptados para Silvopastoreo:**
#
# 1. **K-Means Clustering Silvopastoril**
#    - **Funcionamiento**: Particiona datos en K clusters minimizando la suma de cuadrados intra-cluster
#    - **Adaptación Silvopastoril**: Segmentación de zonas con diferentes balances sombra-luz, análisis de composición láctea por dieta silvopastoril
#    - **Aplicación Específica**:
#      - Crear mapas de "zonas de confort térmico" integrando sombra arbórea + disponibilidad de agua + calidad de pastura
#      - Segmentar perfiles de calidad láctea correlacionados con % de consumo de follaje arbóreo vs pastura
#    - **Justificación Técnica**: Eficiente para datos GPS de animales, parámetros microclimáticos y composición nutricional de la leche
#
# 2. **DBSCAN Regenerativo**
#    - **Funcionamiento**: Agrupa puntos densos y marca como outliers los puntos en regiones de baja densidad
#    - **Adaptación Silvopastoril**: Detección de patrones de pastoreo rotativo, identificación de "hotspots" de regeneración del suelo
#    - **Aplicación Específica**:
#      - Identificar zonas de sobrepastoreo o subpastoreo mediante densidad de GPS animal + tiempo de residencia
#      - Detectar anomalías en vocalizaciones que indiquen estrés por cambio dietario (inclusión de follaje arbóreo)
#    - **Justificación**: No requiere K predefinido; excelente para detectar comportamientos emergentes en sistemas regenerativos complejos
#
# **Algoritmos No Vistos en Clase - Específicos para Agroforestería:**
#
# 3. **Gaussian Mixture Models Silvopastoriles (GMM)**
#    - **Funcionamiento**: Modela datos como mezcla de distribuciones Gaussianas con asignación probabilística
#    - **Adaptación Silvopastoril**: Modelado probabilístico de la "transición gradual" entre zonas de ecosistema (sombra densa → sombra parcial → pastura abierta)
#    - **Aplicación Específica**:
#      - Clasificación "suave" de microzonas silvopastoriles con solapamientos naturales (ej: 70% sombra + 30% pastura)
#      - Modelado probabilístico de calidad láctea como función continua de diversidad dietaria arbórea
#    - **Justificación**: Los sistemas silvopastoriles tienen transiciones graduales, no límites discretos; GMM captura esta continuidad
#
# 4. **HDBSCAN Regenerativo Jerárquico**
#    - **Funcionamiento**: Extiende DBSCAN con jerarquía, maneja densidades variables y extrae clusters estables
#    - **Adaptación Silvopastoril**: Análisis jerárquico de regeneración (individual → rodal → paisaje) y comportamiento animal multi-escala
#    - **Aplicación Específica**:
#      - Análisis multi-escala: comportamiento individual animal → hato → ecosistema silvopastoril
#      - Clustering jerárquico de imágenes de dron: hoja individual → árbol → rodal → sistema silvopastoril completo
#    - **Justificación**: Los sistemas silvopastoriles tienen múltiples escalas espaciales y temporales; HDBSCAN captura esta jerarquía natural
#
# ---
#
# ### 📊 **¿Qué métricas de evaluación utilizarás y por qué?**
#
# #### **🎵 Para Animal Sounds Dataset (Audio Silvopastoril)**
#
# **Métricas Primarias - Adaptadas para Silvopastoreo:**
# - **Silhouette Score Estacional (↑)**:
#   - **Adaptación**: Evaluar clustering de vocalizaciones considerando variaciones estacionales de dieta (más follaje en verano, más pastura en invierno)
#   - **Justificación Silvopastoril**: Las características espectrales cambian con dieta arbórea; necesitamos clustering robusto a variabilidad estacional
#   - **Implementación**: Calcular Silhouette Score por estación y promediarlo ponderadamente
#
# **Métricas Secundarias:**
# - **Calinski-Harabasz Index Microclimático (↑)**:
#   - **Adaptación**: Incorporar variables microclimáticas (temperatura bajo sombra vs pasturas abiertas) en el cálculo
#   - **Justificación**: Vocalizaciones de estrés térmico son críticas en sistemas silvopastoriles; CH debe ser sensible a estas diferencias
#
# #### **🌿 Para PlantVillage Dataset (Imágenes Silvopastoriles de Dron)**
#
# **Métricas Primarias - Ecosistemas Integrados:**
# - **Davies-Bouldin Index Multi-Especie (↓)**:
#   - **Adaptación**: Evaluar clustering considerando interacciones árbol-arbusto-pastura, no solo especies individuales
#   - **Justificación Silvopastoril**: Salud del sistema depende de interacciones; DB debe penalizar clustering que ignore simbiosis
#   - **Implementación**: Ponderar DB por densidad de cobertura vegetal y diversidad de estratos
#
# **Métricas Secundarias:**
# - **Adjusted Rand Index Regenerativo (ARI)**:
#   - **Adaptación**: Validar clustering contra índices de regeneración conocidos (carbono del suelo, biodiversidad)
#   - **Justificación**: Medir qué tan bien el clustering no-supervisado predice regeneración real del ecosistema
#
# #### **🥛 Para Milk Quality Dataset (Calidad Láctea Silvopastoril)**
#
# **Métricas Primarias - Nutrición Diversificada:**
# - **Calinski-Harabasz Index Nutricional (↑)**:
#   - **Adaptación**: Incorporar variables de diversidad dietaria (% follaje, % frutos, % pastura) en el análisis
#   - **Justificación Silvopastoril**: Calidad láctea en sistemas silvopastoriles refleja diversidad nutricional; CH debe capturar estos patrones complejos
#   - **Implementación**: Ponderar variables fisicoquímicas por correlación con diversidad dietaria
#
# **Métricas Secundarias:**
# - **Isolation Score Estacional**:
#   - **Adaptación**: Detectar anomalías considerando disponibilidad estacional de forraje arbóreo
#   - **Justificación**: Contaminación vs cambios naturales por dieta silvopastoril requiere contexto estacional
#
# #### **🌳 Métricas Específicas para Silvopastoreo**
#
# **Índice de Integración Silvopastoril (IIS) - Métrica Original:**
# - **Definición**: IIS = (Silhouette_Audio × 0.3) + (DB_Imágenes × 0.4) + (CH_Leche × 0.3)
# - **Justificación**: Métrica compuesta que evalúa éxito del sistema integrado, no componentes aislados
# - **Interpretación**: IIS > 0.7 indica sistema silvopastoril bien integrado y funcionalmente estable
#
# **Validación Temporal Regenerativa:**
# - **Implementación**: Validar modelos en ciclos de 2-3 años para capturar efectos de regeneración del suelo
# - **Justificación**: Sistemas regenerativos muestran mejoras graduales; validación anual es insuficiente
#
# ---
#
# ### 👥 **¿Quiénes serían los usuarios o beneficiarios del modelo?**
#
# **Usuarios Primarios Silvopastoriles**:
# - **Productores silvopastoriles** de Los Ríos/Los Lagos: Transición desde ganadería convencional hacia sistemas regenerativos
# - **Consultores en agroforestería**: Diseño e implementación de sistemas silvopastoriles específicos para el sur de Chile
# - **Cooperativas lácteas regenerativas**: Certificación y trazabilidad de productos de silvopastoreo
# - **Veterinarios especializados en bienestar silvopastoril**: Monitoreo de salud animal en sistemas regenerativos
#
# **Beneficiarios Ecosistémicos**:
# - **CONAF y SAG**: Monitoreo de servicios ecosistémicos y cumplimiento de normativas ambientales
# - **Centros de certificación de carbono**: Validación de captura de CO₂ en sistemas silvopastoriles
# - **INIA y universidades**: Investigación aplicada en sistemas regenerativos del sur de Chile
# - **Comunidades rurales**: Diversificación de ingresos (carbono, madera, ecoturismo) y resiliencia climática
#
# **Impacto Estimado Silvopastoril**: 200+ productores en transición regenerativa, 50+ parcelas piloto, certificación de 10,000+ ha silvopastoriles
#
# ---
#
# ### 🎯 **¿Qué esperas lograr con tu modelo? (Objetivos Silvopastoriles Específicos)**
#
# **1. Segmentación Automática Regenerativa**:
# - **Zonas Microclimáticas**: Mapeo automático de gradientes sombra-luz-agua para optimización de bienestar animal
# - **Perfiles de Calidad Láctea Silvopastoril**: Correlación entre diversidad dietaria arbórea y composición nutricional de la leche
# - **Patrones de Pastoreo Regenerativo**: Identificación automática de rotaciones óptimas que maximicen regeneración del suelo
#
# **2. Detección de Anomalías Ecosistémicas**:
# - **Estrés Silvopastoril**: Vocalizaciones que indiquen desbalance en sistema árbol-animal-suelo
# - **Degradación del Sistema**: Detección temprana de pérdida de diversidad o funcionalidad ecosistémica
# - **Oportunidades de Mejora**: Identificación de zonas con potencial para intensificación regenerativa
#
# **3. Optimización Inteligente del Sistema**:
# - **Carga Animal Regenerativa**: Balance óptimo entre productividad y regeneración ecosistémica
# - **Sincronización Estacional**: Optimización de rotaciones según fenología de árboles y arbustos
# - **Gestión Adaptativa**: Ajuste automático de manejo según retroalimentación del ecosistema
#
# **4. Visualización de Estructura Latente Silvopastoril**:
# - **Mapas de Conectividad Ecosistémica**: Visualización de flujos de nutrientes, agua y energía en el sistema
# - **Dashboards de Regeneración**: Indicadores integrados de salud del ecosistema silvopastoril
# - **Herramientas de Diseño**: Apoyo para planificación de nuevos sistemas silvopastoriles
#
# ---
#
# ### 🛠️ **¿Qué herramientas planeas usar? (Stack Tecnológico Silvopastoril)**
#
# **Ecosistema Python Científico**:
# - **Pandas & NumPy**: Análisis de datos temporales de ecosistemas y correlaciones árbol-animal-suelo
# - **Matplotlib & Seaborn**: Visualización de ciclos regenerativos y patrones estacionales
#
# **Machine Learning & Clustering Especializados**:
# - **scikit-learn**: K-Means para zonificación silvopastoril, GMM para transiciones ecosistémicas
# - **hdbscan**: Análisis jerárquico multi-escala (individuo → hato → ecosistema)
# - **umap-learn**: Reducción dimensional para visualización de complejidad silvopastoril
#
# **Procesamiento Especializado Silvopastoril**:
# - **librosa**: Análisis de vocalizaciones en ambientes forestales (filtrado de ruido de viento, hojas)
# - **rasterio + GDAL**: Procesamiento de imágenes multiespectrales de dron para mapeo de cobertura arbórea
# - **scikit-image**: Segmentación automática de estratos vegetales (dosel, sotobosque, pastura)
#
# **Sensórica IoT Rural**:
# - **PySerial**: Comunicación con sensores de campo (humedad suelo, temperatura, GPS animal)
# - **MQTT**: Protocolo de comunicación para redes IoT de gran alcance en zonas rurales
# - **InfluxDB**: Base de datos de series temporales para datos ambientales continuos
#
# **Geoespacial y Drones**:
# - **QGIS + Python**: Análisis geoespacial de parcelas silvopastoriles
# - **OpenDroneMap**: Procesamiento de imágenes de dron para ortomosaicos y modelos 3D
# - **Folium**: Visualización web interactiva de sistemas silvopastoriles
#
# **Justificación Técnica Regenerativa**:
# - **Enfoque multi-escala**: Herramientas que manejen desde análisis de hoja individual hasta paisajes completos
# - **Robustez temporal**: Stack preparado para análisis de ciclos de regeneración de 2-10 años
# - **Integración campo-laboratorio**: Conectividad entre sensores remotos y análisis de muestras
#
# ---
#
# ### 🌟 Conclusión: Plan Técnico Integrado para el Sur de Chile
#
# Esta propuesta metodológica se fundamenta en el análisis exhaustivo de 10 datasets, la evaluación contextualizada para sistemas **silvopastoriles del sur de Chile**, y la selección estratégica de 3 datasets complementarios adaptados para **agroforestería regenerativa**.
#
# **Innovación Clave**: Primera aplicación de ML no supervisado específicamente diseñada para sistemas **silvopastoriles regenerativos**, integrando:
# - 🌳 Monitoreo de ecosistemas árbol-animal-suelo
# - 🔊 Análisis de bienestar animal en ambientes forestales
# - 🥛 Correlación de calidad láctea con diversidad dietaria silvopastoril
# - 🤖 Automatización inteligente de pastoreo regenerativo
#
# **Plan de Implementación Realista (24 meses)**:
# 1. **Meses 1-6**: Establecimiento parcelas piloto + sensórica IoT
# 2. **Meses 7-12**: Desarrollo algoritmos ML adaptados + validación inicial
# 3. **Meses 13-18**: Integración sistemas + dashboards regenerativos
# 4. **Meses 19-24**: Escalamiento + transferencia tecnológica a productores
#
# La combinación de algoritmos de aprendizaje no supervisado, métricas específicamente justificadas para silvopastoreo, y herramientas especializadas en ecosistemas integrados garantiza una aproximación técnicamente sólida y prácticamente aplicable al desarrollo de **inteligencia artificial para la regeneración ecosistémica rural del sur de Chile**.
